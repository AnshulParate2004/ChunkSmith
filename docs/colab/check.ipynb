# %%
import pickle
with open(r"D:\MultiModulRag\Backend\data\pickle\10th hindi sl 2020-21-10-20 (1)_20251113_113909_checkpoint1.pkl","rb") as f:
    data = pickle.load(f)
print(data)
# Out:
# [<unstructured.documents.elements.CompositeElement object at 0x0000013D38FCDD50>, <unstructured.documents.elements.CompositeElement object at 0x0000013D4F889E10>, <unstructured.documents.elements.CompositeElement object at 0x0000013D4F895490>, <unstructured.documents.elements.CompositeElement object at 0x0000013D4F896FD0>, <unstructured.documents.elements.CompositeElement object at 0x0000013D4F8A6910>, <unstructured.documents.elements.CompositeElement object at 0x0000013D4F8BD3D0>]

# %%
data

# %%
data[0].metadata.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data[0].metadata.content
#
# NameError: name 'data' is not defined
